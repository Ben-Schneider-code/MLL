# %% [markdown]
# # Categorical Data, One-Hot Encoding, and the curse of dimensionality
#
# Let D be our input domain of n-dimensional categorical input vectors and Y = {y<sub>1</sub>, y<sub>2</sub>,... y<sub>k</sub>} be the classification output domain.
# f: D -> Y is a classification function.
# ![intro.jpg](attachment:intro.jpg)

# %% [markdown]
# **Idea:** get rid of sparse features in the 1-hot encoding
# -> limit to most common 1-hot categories
# for a feature f pick the t most common 1-hot values.
# convert f to be a t+1 dim vector where the t+1th is the 'other' value

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  
device = torch.device(dev)  
print(device)
# Out:
# cuda:0
